// %% [markdown]
// ## 最初のコードの例
//
// 次のセルには、一般的なC++プログラミングに頻繁に使われるコードの最初の例が含まれています。カーソルをコードの行の上に重ねて、playボタンをクリックすると、説明を聞けます。以下にある**レビュー**欄でも情報の確認ができます。

// %%
#include <iostream>
using std::cout;

cout << "Hello!" << "\n";

// %% [markdown]
// ## レビュー
//
// `#include <iostream>`
//
// - `#include`はコードがコンパイルされる前に実行されるプリプロセッサのコマンドです。このコマンドは`iostream`というヘッダファイルを検索して、その内容をプログラムに貼り付けます`iostream`には入力/出力ストリームオブジェクトの宣言が含まれます。
//
// `using std::cout;`
//
// - 名前空間は、C++で識別子（名前）をグループ化するための方法です。名前空間は識別子に文脈を与えて、名前の衝突を防ぎます。名前空間`std`は、標準ライブラリで使用される名前空間です。
// -`using`コマンドは`std::cout`をプログラムのグローバルスコープに追加します。これにより、コードの中で`std::cout`と書かなくても`cout`を使うことができます。
// -`cout`は出力ストリームで、ノートブックやターミナルを使用している場合には、それらに出力を送るために使用します。
// - 例の2行目は、セミコロン`;`で終わっていることに注意してください。C++では、コーディング文の最後にセミコロンを付けます。なお，`#include`文はプリプロセッサのコマンドなので，セミコロンは必要ありません。
//
// `cout << "Hello!" << "\n";`
//
// - この行では、コードが`cout`を使ってノートブックに出力を送っています。演算子`<<`はストリーム挿入演算子で、演算子の右側にあるものを左側に書き出します。つまりこの場合は、`"Message here"`が出力ストリーム`cout`に書き込まれます。
